# %%
import numpy as np
import lightgbm as lgb
import pickle

info = {
    'building_style':1,
    'days_on_market':1,
    'la':43.778614,
    'lo':-79.451805,
    'ownership_type':0,
    'property_type':0,
    'square_footage_filter':7,
    'transaction_type':1,
    'washrooms':2,
    'year':2019,
    'month':3,
    'hpi':251.1,
    'total_beds':2,
}

arr = []
for val in info:
    arr.append(info[val])
df_full_mdl = pickle.load(open('lgbm.sav', 'rb'))
pred = df_full_mdl.predict([arr])
print(arr)
np.expm1(pred) # 568828
# Out:
# [1, 1, 43.778614, -79.451805, 0, 0, 7, 1, 2, 2019, 3, 251.1, 2]
# array([461520.71901472])
