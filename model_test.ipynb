# %%
import numpy as np
import lightgbm as lgb
import pickle

data = {
    'total_beds':3,
    'washrooms':2,
    'square_footage_filter':10,
    'la':43.6648433,
    'lo':-79.3370509,
    'year':2019,
    'month':3,
    'hpi':251.1,
    'days_on_market':1,
    'ownership_type':1,
    'property_type':1,
    'transaction_type':1,
    'building_style':2,
}

arr = []
for val in info:
    arr.append(data[val])
df_full_mdl = pickle.load(open('lgbm.sav', 'rb'))
pred = df_full_mdl.predict([arr])
np.expm1(pred) # 568828
# Out:
# array([15353.77381439])
