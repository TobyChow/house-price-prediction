# %%
import numpy as np
import lightgbm as lgb
import pickle
df_tt = [[2, 1, 43.6648433, -79.3370509, 1, 1, 10, 1, 2, 2019, 3, 251.1, 3]]
df_full_mdl = pickle.load(open('lgbm.sav', 'rb'))
pred = df_full_mdl.predict(df_tt)
np.expm1(pred) # 568828
	building_style	days_on_market	la	lo	ownership_type	property_type	square_footage_filter	transaction_type	washrooms	year	month	hpi	total_beds
0	2	1.0	43.664843	-79.337051	1	1	10	1	2	2019	3	251.1	3
# Out:
# array([1409197.99566286])
